# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
import json
import numpy
from IPython.display import display
from subprocess import check_output
import sys
import traceback
from tqdm.notebook import tqdm, trange
import plotly.graph_objects as go
import plotly.express as px
from paramiko import SSHClient
from scp import SCPClient
from subprocess import call

# %%
techs = {
    "tech1": "1q_1o",
    "tech2": "k_per_terra",
    "tech3": "4pip",
    "tech4": "7vp",
    "tech5": "1o_1pw",
    "tech6": "1k_1c",
    "tech7": "3vp_per_gaia_place",
    "tech8": "4c",
    "tech9": "4pw",
    # idk wtf this is --> "tech-ship0"
}

adv_techs = {
    "advtech1": "3vp_per_fed_pass",
    "advtech2": "2vp_per_tech_bump",
    "advtech3": "1qic_5c_action",
    "advtech4": "2vp_per_mine",
    "advtech5": "3vp_per_rl_pass",
    "advtech6": "1o_per_sector",
    "advtech7": "1vp_per_terra_pass",
    "advtech8": "2vp_per_gaia",
    "advtech9": "4vp_per_ts",
    "advtech10": "2vp_per_sector",
    "advtech11": "3o_action",
    "advtech12": "5vp_per_fed",
    "advtech13": "3k_action",
    "advtech14": "3vp_per_mine_place",
    "advtech15": "3vp_per_ts_place",
}

feds = {
    "fed1": "12vp",
    "fed2": "qic",
    "fed3": "2pw",
    "fed4": "2o",
    "fed5": "6c",
    "fed6": "2k",
    "gleens": "gleens"
}

round_scorings = {
    "score1": "2vp_per_terra",
    "score2": "2vp_per_research_bump",
    "score3": "2vp_per_mine_place",
    "score4": "5vp_per_fed_place",
    "score5": "4vp_per_ts_place",
    "score6": "4vp_per_gaia_place",
    "score7": "5vp_per_3pip_place",
    "score8": "3vp_per_ts_place",
    "score9": "3vp_per_gaia_place",
    "score10": "5vp_per_3pip_place",
}

boosters = {

    "booster1": "1k_1o",
    "booster2": "2pwt_1o",
    "booster3": "1qic_2c",
    "booster4": "2c_terra",
    "booster5": "2pw_nav",
    "booster6": "1o_1vp_per_mine",
    "booster7": "1o_2vp_per_ts",
    "booster8": "1k_3vp_per_rl",
    "booster9": "4pw_4vp_per_3pip",
    "booster10": "4c_1vp_per_gaia",
}

bad_buildings = {"colony", 
                 "colonyShip", 
                 "tradeShip", 
                 "constructionShip", 
                 "researchShip",
                 "scout",
                 "frigate",
                 "battleShip",
                 "customsPost",
                 "tradePost"
                }

factions = {
    "terrans",
    "lantids",
    "hadsch-hallas",
    "ivits",
    "baltaks",
    "geodens",
    "xenos",
    "gleens",
    "ambas",
    "taklons",
    "bescods",
    "firaks",
    "itars",
    "nevlas"
}

# %%
dat_2 = pd.read_pickle("two_players_data")
dat_3 = pd.read_pickle("three_players_data")
dat_4 = pd.read_pickle("four_players_data")

# %%
dat_2["tech_terra"]
# Out:
# 0       3vp_per_gaia_place
# 1                   1o_1pw
# 2              k_per_terra
# 3                      7vp
# 4                     4pip
#                ...
# 8020                   7vp
# 8021                   4pw
# 8022                 1q_1o
# 8023                    4c
# 8024                1o_1pw
# Name: tech_terra, Length: 8025, dtype: object

# %%
def plot_techs(num_players, dat_x):
    for faction in factions:
        factions_pos = []
        for pos in range(num_players):
            dat = dat_x[dat_x['pos_' + str(pos + 1) + '_dropped'] == False]
            factions_pos.append(dat[dat["pos_" + str(pos + 1) +"_faction"] == faction])
        factions_in = pd.concat(factions_pos, ignore_index=True)


        if len(factions_in) == 0:
            factions_in.head()
            raise ValueError('faction not found: ' + faction)

        fig = go.Figure()

        x = []
        for val in techs.values():
            x.append(val)


        for i in range(num_players):
            y = []
            for tech in techs.values():
                df = factions_pos[i]
                y.append(len(df[df['pos_' + str(i + 1) + '_tech_taken_' + tech] == True]) / len(factions_in))

            fig.add_trace(go.Bar(x=x, y=y, name='pos_' + str(i+1)))



        fig.update_layout(barmode='stack')
        fig.update_xaxes(categoryorder='total ascending')
        fig.update_layout(title_text=faction)

        fig.show()

# %%
def plot_tech_tracks(dat_x, num_players):
    for faction in factions:
    
        tech_slots = [
        "tech_terra", 
        "tech_nav",
        "tech_int",
        "tech_gaia",
        "tech_eco",
        "tech_sci"
        ]

        factions_pos = []
        for pos in range(num_players):
            dat = dat_4[dat_4['pos_' + str(pos + 1) + '_dropped'] == False]
            factions_pos.append(dat[dat["pos_" + str(pos + 1) +"_faction"] == faction])
        factions_in = pd.concat(factions_pos, ignore_index=True)

        techs_list = list(techs.values())

        slot_scores = []
        for i in range(len(tech_slots) + 1):
            slot_scores.append([])

        game_nums = []
        for i in range(len(tech_slots) + 1):
            game_nums.append([])

        fig = go.Figure()

        for tech in techs.values():
            not_taken_score = 0
            not_taken_amount = 0
            for i, slot in enumerate(tech_slots):
                taken_score = 0
                taken_amount = 0
                for pos in range(num_players):
                    df = factions_pos[pos]
                    df = df[df[slot] == tech]
                    df_not_taken = df[df['pos_' + str(pos + 1) + "_tech_taken_" + tech] == False]
                    not_taken_score += df_not_taken['pos_' + str(pos + 1) + "_score"].mean()
                    not_taken_amount += len(df_not_taken)
                    df_taken = df[df['pos_' + str(pos + 1) + "_tech_taken_" + tech] == True]
                    taken_score += df_taken['pos_' + str(pos + 1) + "_score"].mean()
                    taken_amount += len(df_taken)
                slot_scores[i].append(taken_score / 4)
                game_nums[i].append(taken_amount)
            slot_scores[-1].append(not_taken_score / 6 / num_players)
            game_nums[-1].append(not_taken_amount)

        tech_slots.append("tech_not_taken")

        colors = [
            'rgba(165, 42, 42, .9)', 
            'rgba(112, 128, 144, .9)', 
            'rgba(38, 166, 91, .9)', 
            'rgba(191, 85, 236, .9)', 
            'rgba(255, 215, 0, .9)', 
            'rgba(3, 138, 255, .9)', 
            'rgba(242, 38, 19, .9)'

        ]

        for i, slot in enumerate(tech_slots):
            fig.add_trace(go.Scatter(
                    x=slot_scores[i],
                    y=techs_list,
                    mode="markers",
                    marker_color=colors[i],
                    name=slot,
                    hovertemplate =
                        '<br><b>Position</b>: ' + slot + 
                        '<br><b>Tech</b>: %{y}' +
                        '<br><b>Ave Score</b>: %{x}' +
                        '<br><b>Num Found</b>: %{text}' + 
                        '<extra></extra>',
                        text = game_nums[i]
            ))


            average_score_overall = 0
            for j in range(4):
                df = factions_pos[j]
                average_score_overall += df['pos_' + str(j + 1) + "_score"].mean()
            average_score_overall = average_score_overall / 4

            fig.add_vline(x=average_score_overall, line_dash="dot", line_width=2,
                      annotation_text="overall average: " + str(round(average_score_overall, 2))
                      )

        text = "Basic Technology Impact on Average Score by Track Taken: " + faction
        fig.update_layout(title=text,
                      xaxis_title="Average Score",
                      yaxis_title="Tech")
        

        fig.show()

# %%
plot_tech_tracks(dat_4, 4)
# Out:
# <div>                            <div id="32a3ed44-b014-4095-95f8-60559d81b474" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32a3ed44-b014-4095-95f8-60559d81b474")) {                    Plotly.newPlot(                        "32a3ed44-b014-4095-95f8-60559d81b474",                        [{"hovertemplate":"<br><b>Position</b>: tech_terra<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(165, 42, 42, .9)"},"mode":"markers","name":"tech_terra","text":["51","64","56","70","46","44","19","32","41"],"x":[144.34136904761905,147.37088509316771,142.8353438228438,146.74805137844612,142.11647727272728,139.13684640522877,139.7202380952381,133.2970238095238,138.44191176470588],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_nav<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(112, 128, 144, .9)"},"mode":"markers","name":"tech_nav","text":["74","58","47","75","49","69","38","45","70"],"x":[140.66576690821256,143.70294117647057,145.240625,146.23530974174568,145.0909090909091,143.85714600045264,143.49242424242422,143.46121794871794,143.18692810457517],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_int<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(38, 166, 91, .9)"},"mode":"markers","name":"tech_int","text":["54","88","64","83","15","26","18","10","29"],"x":[144.88098086124404,146.49766234996414,145.92320075757576,146.1788812033377,148.47857142857143,141.2043650793651,156.125,134.0,145.22222222222223],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_gaia<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(191, 85, 236, .9)"},"mode":"markers","name":"tech_gaia","text":["35","43","60","59","17","18","21","14","25"],"x":[147.25208333333336,147.18372183372185,142.84172635145174,147.34785353535352,141.52916666666667,146.54166666666669,147.20138888888889,138.29166666666666,143.77777777777777],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_eco<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(255, 215, 0, .9)"},"mode":"markers","name":"tech_eco","text":["34","50","53","67","50","64","20","30","44"],"x":[147.8407738095238,145.18907342657343,142.75367647058823,145.63796811740892,144.4019138755981,139.30714285714285,146.875,139.54987373737373,141.96753246753246],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_sci<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(3, 138, 255, .9)"},"mode":"markers","name":"tech_sci","text":["68","68","63","67","62","87","26","44","82"],"x":[140.92592387832326,147.40524488304092,141.1131047315258,144.97109885620915,147.91294642857144,146.83912655971483,145.55119047619047,145.51586538461538,139.61934210526314],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_not_taken<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba( ...
# <div>                            <div id="44dbd598-ddf7-4acb-8bd4-9968a27e9b63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44dbd598-ddf7-4acb-8bd4-9968a27e9b63")) {                    Plotly.newPlot(                        "44dbd598-ddf7-4acb-8bd4-9968a27e9b63",                        [{"hovertemplate":"<br><b>Position</b>: tech_terra<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba(165, 42, 42, .9)"},"mode":"markers","name":"tech_terra","text":["105","103","46","91","19","43","6","56","48"],"x":[145.25972167325426,143.55816511387164,147.52083333333331,149.31156832298137,null,142.52777777777777,144.0,143.5856092436975,143.46631493506493],"y":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_nav<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{text}<extra></extra>","marker":{"color":"rgba
["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"type":"scatter"},{"hovertemplate":"<br><b>Position</b>: tech_not_taken<br><b>Tech</b>: %{y}<br><b>Ave Score</b>: %{x}<br><b>Num Found</b>: %{t ...

# %%
def plot_tech_freq(dat_x, num_players):
    for faction in factions:
        factions_pos = []
        for pos in range(num_players):
            dat = dat_x[dat_x['pos_' + str(pos + 1) + '_dropped'] == False]
            factions_pos.append(dat[dat["pos_" + str(pos + 1) +"_faction"] == faction])
        factions_in = pd.concat(factions_pos, ignore_index=True)


        if len(factions_in) == 0:
            factions_in.head()
            raise ValueError('faction not found: ' + faction)

        fig = go.Figure()

        x = []
        for val in techs.values():
            x.append(val)


        #get overall percents for printing
        overall = [0] * len(techs.values())
        for i in range(num_players):
            for j, tech in enumerate(techs.values()):
                df = factions_pos[i]

                freq_taken = len(df[df['pos_' + str(i + 1) + '_tech_taken_' + tech] == True]) / len(factions_in)
                overall[j] += freq_taken

        for i in range(num_players):
            y = []
            info = []
            for j, tech in enumerate(techs.values()):
                df = factions_pos[i]

                freq_taken = len(df[df['pos_' + str(i + 1) + '_tech_taken_' + tech] == True]) / len(factions_in)
                y.append(round(freq_taken * 100, 3))
                info.append(round(((freq_taken / overall[j]) * 100), 3))
            fig.add_trace(go.Bar(x=x, y=y, name='rank_' + str(i+1),                 
                                 hovertemplate =
                                    '<br><b>Rank</b>: ' + str(i+1) + 
                                    '<br><b>Tech</b>: %{x}' +
                                    '<br><b>% Taken for Rank</b>: %{y}' +
                                    '<br><b>% Rank if Taken</b>: %{text}' +
                                    '<br><b>% Rank overall</b>: ' + str(round((len(factions_pos[i]) / len(factions_in)) * 100, 2)) +
                                    '<extra></extra>', 
                                    text=info, 
                                    texttemplate=''))


        title_text = "Frequency Basic Tech Tile is Taken and the Resulting Rank Distribution: " + faction

        fig.update_layout(uniformtext_minsize=100000, uniformtext_mode='hide')
        fig.update_layout(barmode='stack')
        fig.update_xaxes(categoryorder='total ascending')
        fig.update_layout(title_text=title_text, xaxis_title="Basic Tech",
                  yaxis_title="Percent of Games Taken")

        fig.show()

# %%
plot_tech_freq(dat_4, 4)
# Out:
# <div>                            <div id="7b7489f9-6d62-4180-9041-ab90f2756652" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b7489f9-6d62-4180-9041-ab90f2756652")) {                    Plotly.newPlot(                        "7b7489f9-6d62-4180-9041-ab90f2756652",                        [{"hovertemplate":"<br><b>Rank</b>: 1<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 19.96<extra></extra>","name":"rank_1","text":["18.317","21.595","18.367","22.917","19.826","22.037","26.778","16.981","19.091"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[9.937,11.638,8.863,13.787,8.147,11.817,5.73,4.834,9.4],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 2<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 23.99<extra></extra>","name":"rank_2","text":["25.413","25.249","22.078","24.256","25.054","25.209","20.921","24.843","21.818"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[13.787,13.608,10.654,14.593,10.295,13.518,4.476,7.073,10.743],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 3<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 27.57<extra></extra>","name":"rank_3","text":["27.558","27.907","27.458","27.827","30.937","26.21","28.452","27.673","28.545"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":
"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 3<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 23.56<extra></extra>","name":"rank_3","text":["24.739","22.85","22.85","21.86","29.237","24.439","22.296","24.578","22.775"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[11.733,9.604,8.812,13.614,3.416,4.851,16.634,6.485,14.059],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 4<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 22.48<extra></extra>","name":"rank_4","text":["21.503","20.966","22.08","19.157","23.305","24.938","17.253","25.516","22.213"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[10.198,8.812,8.515,11.931,2.723,4.95,12.871,6.733,13.713],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""}," ...
# <div>                            <div id="00c9804a-9512-43fb-9136-e78d7b3ea1b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00c9804a-9512-43fb-9136-e78d7b3ea1b7")) {                    Plotly.newPlot(                        "00c9804a-9512-43fb-9136-e78d7b3ea1b7",                        [{"hovertemplate":"<br><b>Rank</b>: 1<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 22.75<extra></extra>","name":"rank_1","text":["22.901","23.93","18.676","25.581","16.432","23.392","25.9","25.538","21.946"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[9.577,9.816,6.305,13.168,2.793,6.385,14.924,13.248,7.741],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 2<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 24.82<extra></extra>","name":"rank_2","text":["23.473","24.903","26.478","24.961","29.577","21.637","25.623","25.846","27.376"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[9.816,10.215,8.939,12.849,5.028,5.906,14.765,13.408,9.657],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 3<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 27.69<extra></extra>","name":"rank_3","text":["28.435","28.988","28.605","28.372","28.638","29.825","26.454","27.846","24.661"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[11.891,11.891,9.657,14.605,4.868,8.14,15.243,14.445,8.699],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 4<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 24.74<extra></extra>","name":"rank_4","text":["25.191","22.179","26.241","21.085","25.352","25.146","22.022","20.769","26.018"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[10.535,9.098,8.859,10.854,4.31,6.864,12.69,10.774,9.178],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""} ...
# <div>                            <div id="309290c2-5bfe-4e52-8c5a-d7ca0a8d6f86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("309290c2-5bfe-4e52-8c5a-d7ca0a8d6f86")) {                    Plotly.newPlot(                        "309290c2-5bfe-4e52-8c5a-d7ca0a8d6f86",                        [{"hovertemplate":"<br><b>Rank</b>: 1<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 26.0<extra></extra>","name":"rank_1","text":["27.722","28.817","25.833","27.722","26.126","26.23","29.622","26.735","26.717"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[22.902,22.827,14.059,22.902,15.344,15.722,11.262,15.722,18.821],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 2<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 29.02<extra></extra>","name":"rank_2","text":["30.741","29.866","30.139","30.924","30.631","30.517","31.412","27.378","29.292"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[25.397,23.658,16.402,25.548,17.989,18.292,11.943,16.1,20.635],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 3<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 23.58<extra></extra>","name":"rank_3","text":["22.507","21.66","23.194","22.049","24.582","24.968","21.074","24.679","22.318"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[18.594,17.158,12.623,18.216,14.437,14.966,8.012,14.512,15.722],"type":"bar"},{"hovertemplate":"<br><b>Rank</b>: 4<br><b>Tech</b>: %{x}<br><b>% Taken for Rank</b>: %{y}<br><b>% Rank if Taken</b>: %{text}<br><b>% Rank overall</b>: 21.39<extra></extra>","name":"rank_4","text":["19.03","19.656","20.833","19.305","18.662","18.285","17.893","21.208","21.674"],"texttemplate":"","x":["1q_1o","k_per_terra","4pip","7vp","1o_1pw","1k_1c","3vp_per_gaia_place","4c","4pw"],"y":[15.722,15.571,11.338,15.949,10.96,10.96,6.803,12.472,15.268],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidt ...
